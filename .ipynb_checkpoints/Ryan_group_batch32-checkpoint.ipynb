# %% [markdown]
# # Facial Recognition Classification

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import os
import shutil
from bing_image_downloader.bing_image_downloader import downloader


directory_list = [
    './ryan_group2/train/',
    './ryan_group2/test/',
]

# create an initial directory
for directory in directory_list:
    if not os.path.isdir(directory):
        os.makedirs(directory)

# function
def dataset_split(query, train_cnt):
    # create a directory
    for directory in directory_list:
        if not os.path.isdir(directory + '/' + query):
            os.makedirs(directory + '/' + query)
    # preparing
    cnt = 0
    for file_name in os.listdir(query):
        if cnt < train_cnt:
            print(f'[Train Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './ryan_group2/train/' + query + '/' + file_name)
        else:
            print(f'[Test Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './ryan_group2/test/' + query + '/' + file_name)
        cnt += 1
    shutil.rmtree(query)

# %%
# data for Hugh Jackman
query = 'Hugh Jackman'
downloader.download(query, limit=80,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 60)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ===============================================
# #1 Downloading image (https://www.thescottishsun.co.uk/wp-content/uploads/sites/2/2019/05/NINTCHDBPICT000470738485.jpg)
# #1 The file has been successfully downloaded.
# #2 Downloading image (https://www.dailypioneer.com/uploads/2019/story/images/big/hugh-jackman-starrer--the-music-man--revival-coming-to-broadway-2019-03-14.jpg)
# #2 The file has been successfully downloaded.
# #3 Downloading image (https://cdn.vox-cdn.com/thumbor/uWtkwb0qrMrOnVKOgWnCn-VuqLk=/0x0:6196x4131/1200x800/filters:focal(2603x1570:3593x2560)/cdn.vox-cdn.com/uploads/chorus_image/image/64641765/1f3f699511.0.jpeg)
# #3 The file has been successfully downloaded.
# #4 Downloading image (https://financerewind.com/wp-content/uploads/2020/09/ezgif-6-dba5517a2f83.jpg)
# #4 The file has been successfully downloaded.
# #5 Downloading image (https://cdn.britannica.com/47/201647-050-C547C128/Hugh-Jackman-2013.jpg)
# [Error] Invalid image, not saving https://cdn.britannica.com/47/201647-050-C547C128/Hugh-Jackman-2013.jpg
# [Info] Issue getting: https://cdn.britannica.com/47/201647-050-C547C128/Hugh-Jackman-2013.jpg
# [Error] No active exception to reraise
# #5 Downloading image (https://resizing.flixster.com/muQjyZRd5nFUi7pH-aU6Du2p46g=/1797x1876/v1.cjs0OTE2MjtqOzE4MjcwOzEyMDA7MTc5NzsxODc2)
# #5 The file has been successfully downloaded.
# #6 Downloading image (https://www.gannett-cdn.com/presto/2018/11/29/USAT/4442e41b-6b62-4b71-af75-da76e938e377-AP_Music_Hugh_Jackman.JPG?crop=3347,1883,x0,y17&amp;width=3200&amp;height=1680&amp;fit=bounds)
# #6 The file has been successfully downloaded.
# #7 Downloading image (https://celebritieshairtransplants.com/wp-content/uploads/2018/09/1-4-683x1024.jpg)
# #7 The file has been successfully downloaded.
# #8 Downloading image (http://syn.org.au/app/uploads/Hugh-Jackman-tour-header-NEW.jpg)
# #8 The file has been successfully downloaded.
# #9 Downloading image (https://entertainment.inquirer.net/files/2017/05/People-Hugh-Jackman_Inte.jpg)
# #9 The file has been successfully downloaded.
# #10 Downloading image (https://blogapi.mainlinemenswear.co.uk/wp-content/uploads/2018/03/3ed1b8ec35809458c427c7b58926195d.jpg)
# #10 The file has been successfully downloaded.
# #11 Downloading image (https://1.bp.blogspot.com/-MXoDJnOnqIg/XWqeVYNHYoI/AAAAAAAAjOw/pUfX07Tio1EQATM2hUJ1AZLyB9zs6PtdwCLcBGAs/s1600/hugh%2Bjackman%2Bsigned%2Bpictures.jpg)
# #11 The file has been successfully downloaded.
# #12 Downloading image (https://celebritieshairtransplants.com/wp-content/uploads/2018/09/0-3-1024x576.jpg)
# #12 The file has been successfully downloaded.
# #13 Downloading image (https://www.sheknows.com/wp-content/uploads/2018/08/putwbmiqhu0kboidx2i5.jpeg)
# #13 The file has been successfully downloaded.
# #14 Downloading image (http://image.tmdb.org/t/p/original/zHaMlPKvyyEkM8OCB0VZZFs8dmY.jpg)
# #14 The file has been successfully downloaded.
# #15 Downloading image (https://www.rollingstone.com/wp-content/uploads/2018/06/rs-190331-464680828.jpg?crop=900:600&amp;width=440)
# #15 The file has been successfully downloaded.
# #16 Downloading image (https://celebrityinsider.org/wp-content/uploads/2020/09/hugh-jackman-cbsnews-com_-e1600619812712.jpeg)
# #16 The file has been successfully downloaded.
# #17 Downloading image (https://s3-ap-southeast-2.amazonaws.com/content.communitynews.com.au/2016/12/14085100/Hugh-Jackman-GettyImages.jpg)
# #17 The file has been successfully downloaded.
# #18 Downloading image (https://akns-images.eonline.com/eol_images/Entire_Site/20121113/600.hugh.ls.121312.jpg?fit=around|1080:1080&amp;output-quality=90&amp;crop=1080:1080;center,top)
# #18 The file has been successfully downloaded.
# #19 Downloading image (http://image.tmdb.org/t/p/original/oOqun0BhA1rLXOi7Q1WdvXAkmW.jpg)
# #19 The file has been successfully downloaded.
# #20 Downloading image (https://pixel.nymag.com/imgs/fashion/daily/2017/05/19/19-Hugh-Jackman.w700.h700.jpg)
# [Error] Invalid image, not saving https://pixel.nymag.com/imgs/fashion/daily/2017/05/19/19-Hugh-Jackman.w700.h700.jpg
# [Info] Issue getting: https://pixel.nymag.com/imgs/fashion/daily/2017/05/19/19-Hugh-Jackman.w700.h700.jpg
# [Error] No active exception to reraise
# #20 Downloading image (http://www.celebritybeliefs.com/wp-content/uploads/2018/06/hugh-jackman-religion-politics-belief-fame.jpg)
# #20 The file has been successfully downloaded.
# #21 Downloading image (https://www.mensjournal.com/wp-content/uploads/mf/hugh-jackman-portrait.jpg?w=2400&amp;h=1350&amp;crop=1&amp;quality=86&amp;strip=all)
# #21 The file has been successfully downloaded.
# #22 Downloading image (https://cdn.newsapi.com.au/image/v1/f6afd36ae8d215ac58c027e664bcffc4?width=1440)
# #22 The file has been successfully downloaded.
# #23 Downloading image (https://media1.popsugar-assets.com/files/thumbor/mdTRmG6ofCO01YMbJNIGv547ytQ/fit-in/728xorig/filters:format_auto-!!-:strip_icc-!!-/2017/08/16/700/n/1922398/14786c7a61b09daa_GettyImages-112468549/i/Hugh-Jackman-Sexy-Pictures.jpg)
# #23 The file has been successfully downloaded.
# #24 Downloading image (https://s.hdnux.com/photos/07/23/65/1916227/14/1200x0.jpg)
# #24 The file has been successfully downloaded.
# #25 Downloading image (https://usercontent1.hubstatic.com/14085402_f520.jpg)
# #25 The file has been successfully downloaded.
# #26 Downloading image (https://static.accessonline.com/uploads/131095.jpg)
# #26 The file has been successfully downloaded.
# #27 Downloading image (https://static.billboard.com/files/media/hugh-jackman-jan-2018-billboard-1548-compressed.jpg)
# #27 The file has been successfully downloaded.
# #28 Downloading image (https://daytimeconfidential.com/.image/t_share/MTI4ODI1NTIyMTg3NzAzNTcw/alo-068252.jpg)
# #28 The file has been successfully downloaded.
# #29 Downloading image (https://static.accessonline.com/uploads/79503.jpg)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [3], in <module>
#       1 # data for Hugh Jackman
#       2 query = 'Hugh Jackman'
# ----> 3 downloader.download(query, limit=80,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
#       4 dataset_split(query, 60)
#
# File ~/Desktop/facial-recognition-project/facial-recognition-project/bing_image_downloader/bing_image_downloader/downloader.py:35, in download(query, limit, output_dir, adult_filter_off, force_replace, timeout)
#      32     os.makedirs("{}/{}/{}".format(cwd, output_dir, query))
#      34 bing = Bing(query, limit, output_dir, adult, timeout)
# ---> 35 bing.run()
#
# File ~/Desktop/facial-recognition-project/facial-recognition-project/bing_image_downloader/bing_image_downloader/bing.py:78, in Bing.run(self)
#      76 for link in links:
#      77     if self.download_count < self.limit:
# ---> 78         self.download_image(link)
#      79     else:
#      80         print("===============================================")
#
# File ~/Desktop/facial-recognition-project/facial-recognition-project/bing_image_downloader/bing_image_downloader/bing.py:54, in Bing.download_image(self, link)
#      51     # Download the image
#      52     print("#{} Downloading image ({})".format(self.download_count, link))
# ---> 54     self.save_image(link, "{}/{}/{}/".format(os.getcwd(), self.output_dir, self.query) + "image_{}.{}".format(
#      55         str(self.download_count), file_type))
#      56     print("#{} The file has been successfully downloaded.".format(self.download_count))
#      57 except Exception as e:
#
# File ~/Desktop/facial-recognition-project/facial-recognition-project/bing_image_downloader/bing_image_downloader/bing.py:33, in Bing.save_image(self, link, file_path)
#      31 def save_image(self, link, file_path):
#      32     request = urllib.request.Request(link, None, self.headers)
# ---> 33     image = urllib.request.urlopen(request, timeout=self.timeout).read()
#      34     if not imghdr.what(None, image):
#      35         print('[Error] Invalid image, not saving {}'.format(link))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:481, in HTTPResponse.read(self, amt)
#     479 else:
#     480     try:
# --> 481         s = self._safe_read(self.length)
#     482     except IncompleteRead:
#     483         self._close_conn()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/http/client.py:630, in HTTPResponse._safe_read(self, amt)
#     623 def _safe_read(self, amt):
#     624     """Read the number of bytes requested.
#     625
#     626     This function should be used when <amt> bytes "should" be present for
#     627     reading. If the bytes are truly not available (due to EOF), then the
#     628     IncompleteRead exception can be used to detect the problem.
#     629     """
# --> 630     data = self.fp.read(amt)
#     631     if len(data) < amt:
#     632         raise IncompleteRead(data, amt-len(data))
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1270     if flags != 0:
#    1271         raise ValueError(
#    1272           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1273           self.__class__)
# -> 1274     return self.read(nbytes, buffer)
#    1275 else:
#    1276     return super().recv_into(buffer, nbytes, flags)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    1128 try:
#    1129     if buffer is not None:
# -> 1130         return self._sslobj.read(len, buffer)
#    1131     else:
#    1132         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# data for Ryan Reynolds
query = 'Ryan Reynolds'
downloader.download(query, limit=80,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 60)

# %%
# data for Jake Gyllenhaal
query = 'Jake Gyllenhaal'
downloader.download(query, limit=80,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 60)

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import datasets, models, transforms

import numpy as np
import time


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # device

# %%
# define transforms_train dataset
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(), # augmentation
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # normalization
])

transforms_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

data_dir = './ryan_group2'
train_datasets = datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms_train)
test_datasets = datasets.ImageFolder(os.path.join(data_dir, 'test'), transforms_test)

train_dataloader = torch.utils.data.DataLoader(train_datasets, batch_size=32, shuffle=True, num_workers=4)
test_dataloader = torch.utils.data.DataLoader(test_datasets, batch_size=32, shuffle=True, num_workers=4)

print('size of training dataset:', len(train_datasets))
print('size of testing dataset:', len(test_datasets))

class_names = train_datasets.classes
print('class:', class_names)

# %%
def imshow(input, title):
    # convert torch.Tensor to numpy
    input = input.numpy().transpose((1, 2, 0))
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    # print image
    plt.imshow(input)
    plt.title(title)
    plt.show()


# call training data in batches
iterator = iter(train_dataloader)

# visualize the batches
inputs, classes = next(iterator)
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])

# %%
model = models.resnet34(pretrained=True)
num_features = model.fc.in_features
# transfer learning
model.fc = nn.Linear(num_features, 3)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %%
num_epochs = 15
model.train()
start_time = time.time()

# repeat the number of epoch
for epoch in range(num_epochs):
    running_loss = 0.
    running_corrects = 0

    # call training data in batches
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_datasets)
    epoch_acc = running_corrects / len(train_datasets) * 100.

    # print the result while training
    print('#{} Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch, epoch_loss, epoch_acc, time.time() - start_time))

# %%
# evaluate the model
model.eval()
start_time = time.time()

with torch.no_grad():
    running_loss = 0.
    running_corrects = 0

    for inputs, labels in test_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        # visualize
        print(f'[Prediction: {class_names[preds[0]]}] (Actual: {class_names[labels.data[0]]})')
        imshow(inputs.cpu().data[0], title='Prediction: ' + class_names[preds[0]])

    epoch_loss = running_loss / len(test_datasets)
    epoch_acc = running_corrects / len(test_datasets) * 100.
    print('[Test Phase] Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch_loss, epoch_acc, time.time() - start_time))
