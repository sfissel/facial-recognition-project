# %% [markdown]
# # Facial Recognition Classification

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import os
import shutil
from bing_image_downloader.bing_image_downloader import downloader


directory_list = [
    './ryan_group4/train/',
    './ryan_group4/test/',
]

# create an initial directory
for directory in directory_list:
    if not os.path.isdir(directory):
        os.makedirs(directory)

# function
def dataset_split(query, train_cnt):
    # create a directory
    for directory in directory_list:
        if not os.path.isdir(directory + '/' + query):
            os.makedirs(directory + '/' + query)
    # preparing
    cnt = 0
    for file_name in os.listdir(query):
        if cnt < train_cnt:
            print(f'[Train Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './ryan_group4/train/' + query + '/' + file_name)
        else:
            print(f'[Test Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './ryan_group4/test/' + query + '/' + file_name)
        cnt += 1
    shutil.rmtree(query)

# %%
# data for Hugh Jackman
query = 'Hugh Jackman'
downloader.download(query, limit=400,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 300)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ...
# #1 Downloading image (https://www.thescottishsun.co.uk/wp-content/uploads/sites/2/2019/05/NINTCHDBPICT000470738485.jpg)
# #1 The file has been successfully downloaded.
# #2 Downloading image (https://www.dailypioneer.com/uploads/2019/story/images/big/hugh-jackman-starrer--the-music-man--revival-coming-to-broadway-2019-03-14.jpg)
# #2 The file has been successfully downloaded.
# #3 Downloading image (https://cdn.vox-cdn.com/thumbor/uWtkwb0qrMrOnVKOgWnCn-VuqLk=/0x0:6196x4131/1200x800/filters:focal(2603x1570:3593x2560)/cdn.vox-cdn.com/uploads/chorus_image/image/64641765/1f3f699511.0.jpeg)
# #3 The file has been successfully downloaded.
# #4 Downloading image (https://financerewind.com/wp-content/uploads/2020/09/ezgif-6-dba5517a2f83.jpg)
# #4 The file has been successfully downloaded.
# #5 Downloading image (https://cdn.britannica.com/47/201647-050-C547C128/Hugh-Jackman-2013.jpg)
# ...

# %%
# data for Ryan Reynolds
query = 'Ryan Reynolds'
downloader.download(query, limit=400,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 300)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ...
# #1 Downloading image (https://im.indiatimes.in/media/content/2019/Jun/just_a_photograph_of_ryan_reynolds_looking_handsome_with_that_smile_1561372961_725x725.jpg)
# #1 The file has been successfully downloaded.
# #2 Downloading image (http://infostarr.com/wp-content/uploads/2018/01/Ryan-Reynolds-actor-802x1024.jpg)
# #2 The file has been successfully downloaded.
# #3 Downloading image (https://haircutinspiration.com/wp-content/uploads/Ryan-Reynolds-classic-regular-taper-without-side-part.jpg)
# #3 The file has been successfully downloaded.
# #4 Downloading image (https://i2.wp.com/pagesix.com/wp-content/uploads/sites/3/2019/02/ryan-reynolds.jpg?quality=90&amp;strip=all&amp;ssl=1)
# #4 The file has been successfully downloaded.
# #5 Downloading image (https://storage.googleapis.com/afs-prod/media/eb4dfa203885495e9ff2fa097f478cd7/3000.jpeg)
# #5 The file has been successfully downloaded.
# ...

# %%
# data for Jake Gyllenhaal
query = 'Jake Gyllenhaal'
downloader.download(query, limit=400,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 300)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ...
# #1 Downloading image (https://image.assets.pressassociation.io/v2/image/production/a9e5d0d9873fe4e5bbca3a4c8b534409Y29udGVudHNlYXJjaCwxNTg2Mzk1ODMy/2.49132958.jpg?w=640)
# #1 The file has been successfully downloaded.
# #2 Downloading image (https://images2.minutemediacdn.com/image/fetch/c_fill,g_auto,f_auto,h_1109,w_1600/https://hiddenremote.com/wp-content/uploads/getty-images/2017/07/873068310.jpeg)
# #2 The file has been successfully downloaded.
# #3 Downloading image (https://media.glamour.com/photos/5696715493ef4b095210fcc1/master/w_1280,c_limit/beauty-2015-09-jake-gyllenhaal-beard-2-main.jpg)
# #3 The file has been successfully downloaded.
# #4 Downloading image (https://i2.wp.com/fashionablymale.net/wp-content/uploads/2018/01/jake-gyllenhaal-gq-australia-february-201813.jpg?resize=900%2C1130&amp;ssl=1)
# #4 The file has been successfully downloaded.
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import datasets, models, transforms

import numpy as np
import time


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # device

# %%
# define transforms_train dataset
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(), # augmentation
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # normalization
])

transforms_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

data_dir = './ryan_group4'
train_datasets = datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms_train)
test_datasets = datasets.ImageFolder(os.path.join(data_dir, 'test'), transforms_test)

train_dataloader = torch.utils.data.DataLoader(train_datasets, batch_size=32, shuffle=True, num_workers=4)
test_dataloader = torch.utils.data.DataLoader(test_datasets, batch_size=32, shuffle=True, num_workers=4)

print('size of training dataset:', len(train_datasets))
print('size of testing dataset:', len(test_datasets))

class_names = train_datasets.classes
print('class:', class_names)
# Out:
# size of training dataset: 900
# size of testing dataset: 300
# class: ['Hugh Jackman', 'Jake Gyllenhaal', 'Ryan Reynolds']

# %%
def imshow(input, title):
    # convert torch.Tensor to numpy
    input = input.numpy().transpose((1, 2, 0))
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    # print image
    plt.imshow(input)
    plt.title(title)
    plt.show()


# call training data in batches
iterator = iter(train_dataloader)

# visualize the batches
inputs, classes = next(iterator)
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])

# %%
model = models.resnet34(pretrained=False)
num_features = model.fc.in_features
# transfer learning
model.fc = nn.Linear(num_features, 3)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=None`.
#   warnings.warn(msg)

# %%
num_epochs = 15
model.train()
start_time = time.time()

# repeat the number of epoch
for epoch in range(num_epochs):
    running_loss = 0.
    running_corrects = 0

    # call training data in batches
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_datasets)
    epoch_acc = running_corrects / len(train_datasets) * 100.

    # print the result while training
    print('#{} Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch, epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# #0 Loss: 1.1136 Acc: 35.1111% Time: 143.9992s
# #1 Loss: 1.0881 Acc: 41.0000% Time: 285.0500s
# #2 Loss: 1.1071 Acc: 40.6667% Time: 427.5073s
# #3 Loss: 0.9693 Acc: 51.2222% Time: 575.9776s
# #4 Loss: 0.8457 Acc: 62.3333% Time: 724.7037s
# #5 Loss: 0.6450 Acc: 77.2222% Time: 874.1286s
# #6 Loss: 0.3820 Acc: 89.4444% Time: 1024.8963s
# #7 Loss: 0.1806 Acc: 96.4444% Time: 1176.5427s
# #8 Loss: 0.0831 Acc: 99.1111% Time: 1329.0464s
# #9 Loss: 0.0492 Acc: 99.0000% Time: 1485.7625s
# #10 Loss: 0.1098 Acc: 97.3333% Time: 1650.7488s
# #11 Loss: 0.2418 Acc: 92.4444% Time: 1806.2668s
# #12 Loss: 0.1413 Acc: 95.3333% Time: 1961.1088s
# #13 Loss: 0.1169 Acc: 96.7778% Time: 2115.2621s
# #14 Loss: 0.0774 Acc: 98.0000% Time: 2269.7128s

# %%
# evaluate the model
model.eval()
start_time = time.time()

with torch.no_grad():
    running_loss = 0.
    running_corrects = 0

    for inputs, labels in test_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        # visualize
        print(f'[Prediction: {class_names[preds[0]]}] (Actual: {class_names[labels.data[0]]})')
        imshow(inputs.cpu().data[0], title='Prediction: ' + class_names[preds[0]])

    epoch_loss = running_loss / len(test_datasets)
    epoch_acc = running_corrects / len(test_datasets) * 100.
    print('[Test Phase] Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# [Prediction: Jake Gyllenhaal] (Actual: Jake Gyllenhaal)
# [Prediction: Jake Gyllenhaal] (Actual: Jake Gyllenhaal)
# [Prediction: Hugh Jackman] (Actual: Hugh Jackman)
# [Prediction: Hugh Jackman] (Actual: Hugh Jackman)
# [Prediction: Ryan Reynolds] (Actual: Ryan Reynolds)
# [Prediction: Ryan Reynolds] (Actual: Jake Gyllenhaal)
# [Prediction: Jake Gyllenhaal] (Actual: Jake Gyllenhaal)
# [Prediction: Hugh Jackman] (Actual: Hugh Jackman)
# [Prediction: Hugh Jackman] (Actual: Hugh Jackman)
# [Prediction: Hugh Jackman] (Actual: Hugh Jackman)
# [Test Phase] Loss: 0.0930 Acc: 95.6667% Time: 38.1163s
