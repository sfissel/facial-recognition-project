# %% [markdown]
# # Facial Recognition Classification

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import os
import shutil
from bing_image_downloader.bing_image_downloader import downloader


directory_list = [
    './female_black/train/',
    './female_black/test/',
]

# create an initial directory
for directory in directory_list:
    if not os.path.isdir(directory):
        os.makedirs(directory)

# function
def dataset_split(query, train_cnt):
    # create a directory
    for directory in directory_list:
        if not os.path.isdir(directory + '/' + query):
            os.makedirs(directory + '/' + query)
    # preparing
    cnt = 0
    for file_name in os.listdir(query):
        if cnt < train_cnt:
            print(f'[Train Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './female_black/train/' + query + '/' + file_name)
        else:
            print(f'[Test Dataset] {file_name}')
            shutil.move(query + '/' + file_name, './female_black/test/' + query + '/' + file_name)
        cnt += 1
    shutil.rmtree(query)

# %%
# data for Jordin Sparks
query = 'Jordin Sparks'
downloader.download(query, limit=120,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 90)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ...
# #1 Downloading image (http://www.hawtcelebs.com/wp-content/uploads/2018/05/jordin-sparks-at-show-dogs-premiere-in-new-york-05-05-2018-12.jpg)
# #1 The file has been successfully downloaded.
# #2 Downloading image (https://www.mostapex.com/wp-content/uploads/2019/03/Jordin-Sparks.jpg)
# #2 The file has been successfully downloaded.
# #3 Downloading image (https://i.pinimg.com/originals/30/f7/4f/30f74f30d7e8aab120f61743287c696e.jpg)
# #3 The file has been successfully downloaded.
# #4 Downloading image (https://wallpapercave.com/wp/wp2278713.jpg)
# #4 The file has been successfully downloaded.
# #5 Downloading image (https://www.essence.com/wp-content/uploads/2017/04/jordin-sparks1.jpg?width=840&amp;height=1120)
# #5 The file has been successfully downloaded.
# ...

# %%
# data for Queen Latifah
query = 'Queen Latifah'
downloader.download(query, limit=120,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 90)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ...
# #1 Downloading image (https://www.essence.com/wp-content/uploads/2015/07/images/2015/04/24/465578117.jpg)
# #1 The file has been successfully downloaded.
# #2 Downloading image (https://cdn.amomama.com/41beed7452a84ddce1c94d290334445c.jpg?width=3231&amp;height=2156)
# #2 The file has been successfully downloaded.
# #3 Downloading image (http://www.jagurltv.com/wp-content/uploads/2020/09/Queen-Latifah.jpg)
# [Info] Issue getting: http://www.jagurltv.com/wp-content/uploads/2020/09/Queen-Latifah.jpg
# [Error] HTTP Error 308: Permanent Redirect
# #3 Downloading image (https://s.blogcdn.com/slideshows/images/slides/735/469/7/S7354697/slug/l/2017-bronzelens-women-superstars-luncheon-1.jpg)
# #3 The file has been successfully downloaded.
# #4 Downloading image (https://www.hawtcelebs.com/wp-content/uploads/2017/07/queen-latifah-arrives-at-good-morning-america-in-new-york-07-20-2017_4.jpg)
# ...

# %%
# data for Alicia Keys
query = 'Alicia Keys'
downloader.download(query, limit=120,  output_dir='./', adult_filter_off=True, force_replace=False, timeout=60)
dataset_split(query, 90)
# Out:
# [Info] Indexing page: 1
# [Info] Indexed 35 Images on Page 1.
# ...
# #1 Downloading image (https://pisco.meaww.com/0c7868de-34fc-449a-b04d-3c1d275febfc.jpg)
# #1 The file has been successfully downloaded.
# #2 Downloading image (https://celebmafia.com/wp-content/uploads/2019/12/alicia-keys-billboard-women-in-music-2019-4.jpg)
# #2 The file has been successfully downloaded.
# #3 Downloading image (https://dehayf5mhw1h7.cloudfront.net/wp-content/uploads/sites/1311/2021/01/25143414/GettyImages-109573351.jpg)
# #3 The file has been successfully downloaded.
# #4 Downloading image (https://www.hawtcelebs.com/wp-content/uploads/2020/11/alicia-keys-in-glamour-magazine-uk-autumn-2020-winter-2021-1.jpg)
# #4 The file has been successfully downloaded.
# #5 Downloading image (https://static-dailymakeover.stylecaster.com/2015/11/alicia-keys-beauty.jpg)
# #5 The file has been successfully downloaded.
# ...

# %%
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision
from torchvision import datasets, models, transforms

import numpy as np
import time


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu") # device

# %%
# define transforms_train dataset
transforms_train = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(), # augmentation
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225]) # normalization
])

transforms_test = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

data_dir = './female_black'
train_datasets = datasets.ImageFolder(os.path.join(data_dir, 'train'), transforms_train)
test_datasets = datasets.ImageFolder(os.path.join(data_dir, 'test'), transforms_test)

train_dataloader = torch.utils.data.DataLoader(train_datasets, batch_size=4, shuffle=True, num_workers=4)
test_dataloader = torch.utils.data.DataLoader(test_datasets, batch_size=4, shuffle=True, num_workers=4)

print('size of training dataset:', len(train_datasets))
print('size of testing dataset:', len(test_datasets))

class_names = train_datasets.classes
print('class:', class_names)
# Out:
# size of training dataset: 270
# size of testing dataset: 90
# class: ['Alicia Keys', 'Jordin Sparks', 'Queen Latifah']

# %%
def imshow(input, title):
    # convert torch.Tensor to numpy
    input = input.numpy().transpose((1, 2, 0))
    
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    input = std * input + mean
    input = np.clip(input, 0, 1)
    # print image
    plt.imshow(input)
    plt.title(title)
    plt.show()


# call training data in batches
iterator = iter(train_dataloader)

# visualize the batches
inputs, classes = next(iterator)
out = torchvision.utils.make_grid(inputs)
imshow(out, title=[class_names[x] for x in classes])

# %%
model = models.resnet34(pretrained=True)
num_features = model.fc.in_features
# transfer learning
model.fc = nn.Linear(num_features, 3)
model = model.to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr=0.001, momentum=0.9)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet34_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet34_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
num_epochs = 15
model.train()
start_time = time.time()

# iterates
for epoch in range(num_epochs):
    running_loss = 0.
    running_corrects = 0

    # call training data in batches
    for inputs, labels in train_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_datasets)
    epoch_acc = running_corrects / len(train_datasets) * 100.

    # print the result while training
    print('#{} Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch, epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# #0 Loss: 0.6938 Acc: 66.2963% Time: 64.7157s
# #1 Loss: 0.4330 Acc: 82.9630% Time: 132.9487s
# #2 Loss: 0.5167 Acc: 83.7037% Time: 199.5628s
# #3 Loss: 0.2261 Acc: 90.0000% Time: 271.1866s
# #4 Loss: 0.3843 Acc: 88.1481% Time: 337.3124s
# #5 Loss: 0.4298 Acc: 88.8889% Time: 405.5656s
# #6 Loss: 0.3355 Acc: 90.3704% Time: 470.2752s
# #7 Loss: 0.1678 Acc: 92.5926% Time: 538.4056s
# #8 Loss: 0.1188 Acc: 96.6667% Time: 604.0386s
# #9 Loss: 0.2521 Acc: 92.2222% Time: 670.2643s
# #10 Loss: 0.1996 Acc: 95.9259% Time: 735.6114s
# #11 Loss: 0.0917 Acc: 97.4074% Time: 799.6255s
# #12 Loss: 0.1147 Acc: 96.2963% Time: 862.8553s
# #13 Loss: 0.1618 Acc: 95.9259% Time: 925.7353s
# #14 Loss: 0.1854 Acc: 94.8148% Time: 988.9051s

# %%
# evaluate the model
model.eval()
start_time = time.time()

with torch.no_grad():
    running_loss = 0.
    running_corrects = 0

    for inputs, labels in test_dataloader:
        inputs = inputs.to(device)
        labels = labels.to(device)

        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

        # visualize
        print(f'[Prediction: {class_names[preds[0]]}] (Actual: {class_names[labels.data[0]]})')
        imshow(inputs.cpu().data[0], title='Prediction: ' + class_names[preds[0]])

    epoch_loss = running_loss / len(test_datasets)
    epoch_acc = running_corrects / len(test_datasets) * 100.
    print('[Test Phase] Loss: {:.4f} Acc: {:.4f}% Time: {:.4f}s'.format(epoch_loss, epoch_acc, time.time() - start_time))
# Out:
# [Prediction: Alicia Keys] (Actual: Alicia Keys)
# [Prediction: Alicia Keys] (Actual: Alicia Keys)
# [Prediction: Jordin Sparks] (Actual: Jordin Sparks)
# [Prediction: Queen Latifah] (Actual: Queen Latifah)
# [Prediction: Queen Latifah] (Actual: Queen Latifah)
# [Prediction: Alicia Keys] (Actual: Alicia Keys)
# [Prediction: Jordin Sparks] (Actual: Jordin Sparks)
# [Prediction: Jordin Sparks] (Actual: Jordin Sparks)
# [Prediction: Queen Latifah] (Actual: Queen Latifah)
# [Prediction: Alicia Keys] (Actual: Alicia Keys)
# [Prediction: Jordin Sparks] (Actual: Jordin Sparks)
# [Prediction: Alicia Keys] (Actual: Alicia Keys)
# [Prediction: Alicia Keys] (Actual: Alicia Keys)
# [Prediction: Alicia Keys] (Actual: Alicia Keys)
# [Prediction: Queen Latifah] (Actual: Queen Latifah)
# [Prediction: Jordin Sparks] (Actual: Jordin Sparks)
# [Prediction: Jordin Sparks] (Actual: Jordin Sparks)
# [Prediction: Jordin Sparks] (Actual: Jordin Sparks)
# [Prediction: Alicia Keys] (Actual: Alicia Keys)
# ...
